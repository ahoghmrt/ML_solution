# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os

# -------------------------------
# Load ML Dataset
# -------------------------------

dataset_path = "ml_training_data/training_data_signals.npz"
if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"Dataset file not found: {dataset_path}")

data = np.load(dataset_path)
X = data["waveforms"]
y = data["labels"].reshape(X.shape[0], -1)
time = data["time"]

print(f"✅ Loaded dataset: {X.shape[0]} samples, each with {X.shape[1]} time bins")
print(f"✅ Label shape: {y.shape}, Time shape: {time.shape}")

# -------------------------------
# Normalize Inputs
# -------------------------------
X_mean = X.mean(axis=1, keepdims=True)
X_std = X.std(axis=1, keepdims=True)
X_norm = (X - X_mean) / (X_std + 1e-8)

# -------------------------------
# Train/Validation Split
# -------------------------------
X_train, X_val, y_train, y_val = train_test_split(X_norm, y, test_size=0.2, random_state=42)

# -------------------------------
# Define Model Architecture
# -------------------------------
model = keras.Sequential([
    layers.Reshape((X.shape[1], 1), input_shape=(X.shape[1],)),
    layers.Conv1D(32, 3, activation='relu'),
    layers.MaxPooling1D(2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(y.shape[1])
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# -------------------------------
# Train Model
# -------------------------------
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    verbose=1
)

# -------------------------------
# Evaluate & Save Results using baseline-subtracted waveforms and truth labels
# Calculate accuracy in numbers
# -------------------------------
# Predict using baseline-subtracted validation waveforms
# Compare predictions to ground truth time-amplitude pairs from truth files
y_pred = model.predict(X_val)
os.makedirs("ml_training_data", exist_ok=True)
# Out:
# ✅ Loaded dataset: 50000 samples, each with 120 time bins
# ✅ Label shape: (50000, 10), Time shape: (120,)
# Epoch 1/30
# 2025-03-24 12:40:38.990762: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 19200000 exceeds 10% of free system memory.
# 1250/1250 [==============================] - 6s 4ms/step - loss: 86.9276 - mae: 5.3132 - val_loss: 38.9481 - val_mae: 4.0948
# Epoch 2/30
# 1250/1250 [==============================] - 4s 3ms/step - loss: 36.3707 - mae: 3.9476 - val_loss: 34.5717 - val_mae: 3.8536
# Epoch 3/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 32.1922 - mae: 3.6872 - val_loss: 30.5254 - val_mae: 3.5472
# Epoch 4/30
# 1250/1250 [==============================] - 4s 4ms/step - loss: 28.6853 - mae: 3.4571 - val_loss: 28.9006 - val_mae: 3.4711
# Epoch 5/30
# 1250/1250 [==============================] - 4s 3ms/step - loss: 26.2782 - mae: 3.2929 - val_loss: 25.0911 - val_mae: 3.2069
# Epoch 6/30
# 1250/1250 [==============================] - 4s 3ms/step - loss: 24.2808 - mae: 3.1509 - val_loss: 23.3803 - val_mae: 3.0895
# Epoch 7/30
# 1250/1250 [==============================] - 4s 3ms/step - loss: 22.7000 - mae: 3.0417 - val_loss: 22.5347 - val_mae: 3.0498
# Epoch 8/30
# 1250/1250 [==============================] - 4s 3ms/step - loss: 21.4173 - mae: 2.9582 - val_loss: 21.5681 - val_mae: 2.9387
# Epoch 9/30
# 1250/1250 [==============================] - 4s 4ms/step - loss: 20.1696 - mae: 2.8633 - val_loss: 20.0192 - val_mae: 2.8641
# Epoch 10/30
# 1250/1250 [==============================] - 4s 3ms/step - loss: 18.8842 - mae: 2.7808 - val_loss: 18.2913 - val_mae: 2.7182
# Epoch 11/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 17.5685 - mae: 2.6927 - val_loss: 17.0714 - val_mae: 2.6399
# Epoch 12/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 16.5864 - mae: 2.6241 - val_loss: 16.9879 - val_mae: 2.6553
# Epoch 13/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 15.6294 - mae: 2.5514 - val_loss: 16.0494 - val_mae: 2.5895
# Epoch 14/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 14.9730 - mae: 2.5011 - val_loss: 15.1260 - val_mae: 2.4851
# Epoch 15/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 14.4597 - mae: 2.4587 - val_loss: 14.9936 - val_mae: 2.4720
# Epoch 16/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 13.8800 - mae: 2.4093 - val_loss: 15.0275 - val_mae: 2.4741
# Epoch 17/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 13.5570 - mae: 2.3830 - val_loss: 14.3519 - val_mae: 2.4143
# Epoch 18/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 13.1753 - mae: 2.3459 - val_loss: 14.7876 - val_mae: 2.4972
# Epoch 19/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 12.8867 - mae: 2.3248 - val_loss: 14.0543 - val_mae: 2.3793
# Epoch 20/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 12.5297 - mae: 2.2922 - val_loss: 13.7030 - val_mae: 2.3491
# Epoch 21/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 12.2666 - mae: 2.2659 - val_loss: 13.2914 - val_mae: 2.2894
# Epoch 22/30
# 1250/1250 [==============================] - 4s 4ms/step - loss: 11.9990 - mae: 2.2462 - val_loss: 13.1570 - val_mae: 2.3409
# Epoch 23/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 11.7794 - mae: 2.2311 - val_loss: 13.4591 - val_mae: 2.3026
# Epoch 24/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 11.6274 - mae: 2.2175 - val_loss: 13.2552 - val_mae: 2.3180
# Epoch 25/30
# 1250/1250 [==============================] - 5s 4ms/step - loss: 11.3573 - mae: 2.1902 - val_loss: 12.5598 - val_mae: 2.2344
# Epoch 26/30
# 1250/1250 [==============================] - 4s 4ms/step - loss: 11.1034 - mae: 2.1643 - val_loss: 12.3465 - val_mae: 2.2362
# Epoch 27/30
# 1250/1250 [==============================] - 4s 4ms/step - loss: 10.9509 - mae: 2.1623 - val_loss: 12.9634 - val_mae: 2.2803
# Epoch 28/30
# 1250/1250 [==============================] - 4s 3ms/step - loss: 10.7200 - mae: 2.1373 - val_loss: 12.1468 - val_mae: 2.2097
# Epoch 29/30
# 1250/1250 [==============================] - 4s 3ms/step - loss: 10.6003 - mae: 2.1281 - val_loss: 12.3998 - val_mae: 2.2174
# Epoch 30/30
# 1250/1250 [==============================] - 4s 3ms/step - loss: 10.4945 - mae: 2.1182 - val_loss: 11.8784 - val_mae: 2.1470
# 313/313 [==============================] - 0s 1ms/step

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
for i in range(0, y.shape[1], 2):
    plt.scatter(y_val[:, i], y_pred[:, i], alpha=0.5, label=f'Signal {i//2 + 1}')
plt.xlabel("True t0")
plt.ylabel("Predicted t0")
plt.title("t0 Prediction")
plt.legend()

plt.subplot(1, 2, 2)
for i in range(1, y.shape[1], 2):
    plt.scatter(y_val[:, i], y_pred[:, i], alpha=0.5, label=f'Signal {i//2 + 1}')
plt.xlabel("True Amplitude")
plt.ylabel("Predicted Amplitude")
plt.title("Amplitude Prediction")
plt.legend()

plt.show()

# %%
# Save model
model.save("ml_training_data/signal_extraction_model.keras")
print("\n✅ Model training complete and saved as 'signal_extraction_model.keras'")
# Out:
# ✅ Model training complete and saved as 'signal_extraction_model.keras'
