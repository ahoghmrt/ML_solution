# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os

# -------------------------------
# Load ML Dataset
# -------------------------------

dataset_path = "ml_training_data/training_data.npz"
if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"Dataset file not found: {dataset_path}")

data = np.load(dataset_path)
X = data["waveforms"]
y = data["labels"].reshape(X.shape[0], -1)
time = data["time"]

print(f"✅ Loaded dataset: {X.shape[0]} samples, each with {X.shape[1]} time bins")
print(f"✅ Label shape: {y.shape}, Time shape: {time.shape}")

# -------------------------------
# Normalize Inputs
# -------------------------------
X_mean = X.mean(axis=1, keepdims=True)
X_std = X.std(axis=1, keepdims=True)
X_norm = (X - X_mean) / (X_std + 1e-8)

# -------------------------------
# Train/Validation Split
# -------------------------------
X_train, X_val, y_train, y_val = train_test_split(X_norm, y, test_size=0.2, random_state=42)

# -------------------------------
# Define Model Architecture
# -------------------------------
model = keras.Sequential([
    layers.Input(shape=(X.shape[1],)),
    layers.Dense(128, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(y.shape[1])
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# -------------------------------
# Train Model
# -------------------------------
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=32,
    verbose=1
)

# -------------------------------
# Evaluate & Save Results using baseline-subtracted waveforms and truth labels
# Calculate accuracy in numbers
# -------------------------------
# Predict using baseline-subtracted validation waveforms
# Compare predictions to ground truth time-amplitude pairs from truth files
y_pred = model.predict(X_val)
os.makedirs("ml_training_data", exist_ok=True)
# Out:
# ✅ Loaded dataset: 10000 samples, each with 120 time bins
# ✅ Label shape: (10000, 10), Time shape: (120,)
# Epoch 1/30
# /home/artur/.local/lib/python3.10/site-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 65ms/step - loss: 1118.7616 - mae: 20.4431 - val_loss: 147.2472 - val_mae: 7.9161
# Epoch 2/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - loss: 148.9122 - mae: 7.9853 - val_loss: 147.0673 - val_mae: 7.9372
# Epoch 3/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 62ms/step - loss: 147.4537 - mae: 7.9354 - val_loss: 146.8832 - val_mae: 7.9317
# Epoch 4/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 149.3842 - mae: 7.9869 - val_loss: 146.9686 - val_mae: 7.9404
# Epoch 5/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - loss: 148.0761 - mae: 7.9522 - val_loss: 147.3706 - val_mae: 7.8865
# Epoch 6/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 70ms/step - loss: 148.8549 - mae: 7.9587 - val_loss: 147.1089 - val_mae: 7.9223
# Epoch 7/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 62ms/step - loss: 151.8266 - mae: 8.0336 - val_loss: 147.6204 - val_mae: 7.9404
# Epoch 8/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 71ms/step - loss: 149.4682 - mae: 7.9681 - val_loss: 147.4457 - val_mae: 7.9066
# Epoch 9/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - loss: 148.6672 - mae: 7.9511 - val_loss: 147.2135 - val_mae: 7.9203
# Epoch 10/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 62ms/step - loss: 149.9473 - mae: 8.0052 - val_loss: 147.5258 - val_mae: 7.9754
# Epoch 11/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - loss: 148.8869 - mae: 7.9666 - val_loss: 146.5995 - val_mae: 7.9449
# Epoch 12/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - loss: 149.1426 - mae: 7.9777 - val_loss: 146.7846 - val_mae: 7.9466
# Epoch 13/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 72ms/step - loss: 148.2339 - mae: 7.9627 - val_loss: 147.4534 - val_mae: 7.9666
# Epoch 14/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - loss: 147.2156 - mae: 7.9346 - val_loss: 144.3015 - val_mae: 7.8315
# Epoch 15/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 72ms/step - loss: 148.4638 - mae: 7.9605 - val_loss: 144.9079 - val_mae: 7.9448
# Epoch 16/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 72ms/step - loss: 142.2822 - mae: 7.8193 - val_loss: 137.3329 - val_mae: 7.6912
# Epoch 17/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - loss: 122.5150 - mae: 7.2732 - val_loss: 85.6103 - val_mae: 6.1394
# Epoch 18/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 82.7763 - mae: 6.0740 - val_loss: 67.0064 - val_mae: 5.5750
# Epoch 19/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 66.8059 - mae: 5.5106 - val_loss: 53.7793 - val_mae: 4.9152
# Epoch 20/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 71ms/step - loss: 54.3960 - mae: 4.9636 - val_loss: 48.3564 - val_mae: 4.7162
# Epoch 21/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - loss: 48.6193 - mae: 4.7350 - val_loss: 45.4260 - val_mae: 4.5696
# Epoch 22/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - loss: 46.5493 - mae: 4.6475 - val_loss: 42.7063 - val_mae: 4.4421
# Epoch 23/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 72ms/step - loss: 43.7181 - mae: 4.5171 - val_loss: 39.2591 - val_mae: 4.2698
# Epoch 24/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 72ms/step - loss: 40.1637 - mae: 4.2905 - val_loss: 36.0664 - val_mae: 4.0520
# Epoch 25/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 72ms/step - loss: 35.8771 - mae: 4.0241 - val_loss: 33.5708 - val_mae: 3.8446
# Epoch 26/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - loss: 33.1336 - mae: 3.8615 - val_loss: 32.7982 - val_mae: 3.8025
# Epoch 27/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 72ms/step - loss: 34.6931 - mae: 3.9188 - val_loss: 30.3366 - val_mae: 3.7141
# Epoch 28/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 72ms/step - loss: 30.7441 - mae: 3.7380 - val_loss: 28.9027 - val_mae: 3.6233
# Epoch 29/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - loss: 28.9792 - mae: 3.6582 - val_loss: 27.1597 - val_mae: 3.5697
# Epoch 30/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - loss: 27.1834 - mae: 3.5533 - val_loss: 24.3282 - val_mae: 3.3822
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
for i in range(0, y.shape[1], 2):
    plt.scatter(y_val[:, i], y_pred[:, i], alpha=0.5, label=f'Signal {i//2 + 1}')
plt.xlabel("True t0")
plt.ylabel("Predicted t0")
plt.title("t0 Prediction")
plt.legend()

plt.subplot(1, 2, 2)
for i in range(1, y.shape[1], 2):
    plt.scatter(y_val[:, i], y_pred[:, i], alpha=0.5, label=f'Signal {i//2 + 1}')
plt.xlabel("True Amplitude")
plt.ylabel("Predicted Amplitude")
plt.title("Amplitude Prediction")
plt.legend()

plt.show()

# %%
# -------------------------------
# Accuracy Metrics
# -------------------------------
from sklearn.metrics import mean_absolute_error, mean_squared_error

for i in range(y.shape[1]):
    mae = mean_absolute_error(y_val[:, i], y_pred[:, i])
    rmse = np.sqrt(mean_squared_error(y_val[:, i], y_pred[:, i]))
    param = "t0" if i % 2 == 0 else "Amplitude"
    signal_num = (i // 2) + 1
    print(f"📊 Signal {signal_num} - {param}: MAE = {mae:.3f}, RMSE = {rmse:.3f}")

# Save model
model.save("ml_training_data/signal_extraction_model.keras")
print("\n✅ Model training complete and saved as 'signal_extraction_model.keras'")
# Out:
# 📊 Signal 1 - t0: MAE = 2.385, RMSE = 3.126
# 📊 Signal 1 - Amplitude: MAE = 2.116, RMSE = 2.464
# 📊 Signal 2 - t0: MAE = 5.758, RMSE = 7.816
# 📊 Signal 2 - Amplitude: MAE = 2.127, RMSE = 2.469
# 📊 Signal 3 - t0: MAE = 6.022, RMSE = 8.105
# 📊 Signal 3 - Amplitude: MAE = 2.156, RMSE = 2.506
# 📊 Signal 4 - t0: MAE = 5.452, RMSE = 7.451
# 📊 Signal 4 - Amplitude: MAE = 2.187, RMSE = 2.535
# 📊 Signal 5 - t0: MAE = 3.467, RMSE = 4.486
# 📊 Signal 5 - Amplitude: MAE = 2.151, RMSE = 2.496
#
# ✅ Model training complete and saved as 'signal_extraction_model.keras'
