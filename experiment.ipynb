# %% [markdown]
# # ADC Waveform Signal Extraction — Experiment Notebook
#
# Run experiments, compare results, and visualize model performance.
#
# **Usage**: Run cells top-to-bottom. Adjust parameters in the config cell below, then execute the pipeline.
